# %% [markdown]
# # Working with prompts

# %%
# setting the environment variables, the keys
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from config import set_environment
# for the keys - as explained early in chapter 2
set_environment()
# Out:
# Setting OPENAI_API_KEY...
# Setting GOOGLE_API_KEY...
# Setting ANTHROPIC_API_KEY...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

# llm = GoogleGenerativeAI(model="gemini-1.5-pro")
llm = GoogleGenerativeAI(model="gemini-2.0-flash")
                         
# First chain generates a story
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | llm | StrOutputParser()

# Second chain analyzes the story
analysis_prompt = PromptTemplate.from_template(
    "Analyze the following story's mood:\n{story}"
)
analysis_chain = analysis_prompt | llm | StrOutputParser()

# Combine chains
story_with_analysis = story_chain | analysis_chain

# Run the combined chain
story_analysis = story_with_analysis.invoke({"topic": "a rainy day"})
print("\nAnalysis:", story_analysis)
# Out:
# Analysis: The mood of the story shifts throughout, but overall it can be described as:
#
# *   **Initially melancholic and oppressive:** The opening paints a picture of gloom, mirroring Amelia's writer's block and inner turmoil. Words like "bruised plum," "heavy," "relentless drumming," "restless heart," "dull and gray," and "swallowed by the storm" contribute to this feeling of sadness and stagnation.
#
# *   **Hopeful and comforting:** The arrival of the cat marks a turning point. The mood gradually shifts toward warmth and hope. Words like "crooned," "warm towel," "cozy cottage," "fragile peace," and "comforting rumble" create a sense of solace and connection.
#
# *   **Inspired and optimistic:** As Amelia cares for the cat and reflects on its resilience, the mood becomes more optimistic. The "fresh eyes," "genuine smile," "effortlessly," "simple beauty," and "full of possibility" indicate a renewed sense of inspiration and hope for the future.
#
# **In summary:** The story begins with a mood of melancholy and despair, transitions to one of comfort and hope, and ultimately concludes with a feeling of inspiration and optimism. The rain serves as a metaphor for Amelia's creative block, which is eventually washed away, leaving room for new ideas and a brighter outlook.

# %% [markdown]
# ## LLMs and prompts

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAI

# Create a template with variables
template = """
Summarize this text in one sentence:

{text}
"""
llm = GoogleGenerativeAI(model="gemini-2.0-flash")

prompt = PromptTemplate.from_template(template)

# Format the prompt with actual values
formatted_prompt = prompt.format(text="Some long story about AI...")

# Use with any LLM, such as the one created in the LLM section
result = llm.invoke(formatted_prompt)
print(result)
# Out:
# Okay, I need the actual text to summarize it. Since you only provided "Some long story about AI...", I can only offer a placeholder:
#
# **This is a long story about artificial intelligence.**

# %% [markdown]
# ## Chat models and prompts

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

template = ChatPromptTemplate.from_messages([
    ("system", "You are an English to French translator."),
    ("user", "Translate this to French: {text}")
])

chat = ChatOpenAI()
formatted_messages = template.format_messages(text="Hello, how are you?")
result = chat.invoke(formatted_messages)
print(result.content)
# Out:
# Salut, comment vas-tu ?
